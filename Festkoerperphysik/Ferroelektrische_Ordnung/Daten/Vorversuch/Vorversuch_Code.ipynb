# %%
import Pkg; Pkg.add("CairoMakie")
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\fynnd\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\fynnd\.julia\environments\v1.12\Manifest.toml`

# %%
using DataFrames
using CairoMakie

# %%
messung = (DataFrame(load(raw"C:\Users\fynnd\OneDrive\Documents\Uni\Praktikum\Praktikum_B\Festkörperphysik\Ferroelektrische_Ordnung\Daten\24_06_26\TestHysterese\4V_30Hz.csv")))
# Out:
# 4999×1 DataFrame
#   Row │ -3.12500000e-02\t6.56250000e-01
#       │ String
# ──────┼─────────────────────────────────
#     1 │ -6.25000000e-02\t6.40625000e-01
#     2 │ -6.25000000e-02\t6.40625000e-01
#     3 │ -9.37500000e-02\t6.40625000e-01
#     4 │ -9.37500000e-02\t6.40625000e-01
#     5 │ -9.37500000e-02\t6.40625000e-01
#     6 │ -9.37500000e-02\t6.40625000e-01
#     7 │ -1.25000000e-01\t6.40625000e-01
#     8 │ -1.56250000e-01\t6.40625000e-01
#   ⋮   │                ⋮
#  4993 │ 6.25000000e-02\t6.56250000e-01
#  4994 │ 6.25000000e-02\t6.71875000e-01
#  4995 │ 3.12500000e-02\t6.56250000e-01
#  4996 │ 3.12500000e-02\t6.71875000e-01
#  4997 │ 0.00000000e+00\t6.56250000e-01
#  4998 │ 0.00000000e+00\t6.40625000e-01
#  4999 │ -3.12500000e-02\t6.56250000e-01
#                        4984 rows omitted
